# %%
import pandas as pd

# %%
producao = pd.read_csv('produção_leite_milh_sorgo.csv', encoding='latin-1', sep=';')
producao
# Out:
#                Localidade  \
# 0   Bela Vista de Goiï¿½s
# 1   Bela Vista de Goiï¿½s
# 2  Bela Vista de Goziï¿½s
# 3                Goianira
# 4                Goianira
# 5                Goianira
#
#                                                            Variï¿½vel    2014  \
# 0                       Produï¿½ï¿½o de Origem Animal - Leite (mil l)  71.000
# 1  Produï¿½ï¿½o Agrï¿½cola - Milho - Total - Quantidade Produzida (t)  25.250
# 2          Produï¿½ï¿½o Agrï¿½cola - Sorgo - Quantidade Produzida (t)   1.500
# 3                       Produï¿½ï¿½o de Origem Animal - Leite (mil l)   4.571
# 4  Produï¿½ï¿½o Agrï¿½cola - Milho - Total - Quantidade Produzida (t)   3.800
# 5          Produï¿½ï¿½o Agrï¿½cola - Sorgo - Quantidade Produzida (t)       -
#
#      2015    2016    2017      2018    2019     2020    2021    2022    2023  \
# 0  71.500  70.000  73.500    79.000  78.000   77.839  78.799  78.851  81.702
# ...

# %%
#producao = producao.replace('-', float('nan'))
#producao
