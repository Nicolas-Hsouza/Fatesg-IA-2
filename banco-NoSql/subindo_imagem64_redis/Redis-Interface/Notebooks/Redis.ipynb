# %%
# Instala a biblioteca "redis" no ambiente do Jupyter/Python.
# O ponto de exclamação "!" é um recurso do Jupyter Notebook:
# ele permite executar comandos do sistema operacional / terminal
# diretamente dentro da célula.
# Neste caso, estamos rodando o comando:
# pip install redis
# que instala o pacote necessário para o Python conversar com o Redis.

# !pip install redis
# Out:
# Collecting redis
#   Downloading redis-7.3.0-py3-none-any.whl.metadata (12 kB)
# Downloading redis-7.3.0-py3-none-any.whl (404 kB)
# Installing collected packages: redis
# Successfully installed redis-7.3.0

# %%
# Importa a biblioteca padrão "json".
# Essa biblioteca serve para:
# - ler arquivos JSON
# - converter texto JSON em objeto Python
# - converter objeto Python em texto JSON
import json

# Importa a biblioteca "redis", que contém a classe Redis
# e os métodos usados para conectar, salvar e ler dados no Redis.
import redis

# Importa a função pprint ("pretty print").
# Ela mostra estruturas grandes (como dicionários e listas)
# de forma mais organizada do que o print comum.
from pprint import pprint

# Cria uma variável chamada caminho_arquivo.
# Variável = um nome que guarda um valor.
# Aqui, esse valor é o caminho completo do arquivo JSON no Windows.
caminho_arquivo = r"C:\Users\nicol\OneDrive\Desktop\Fatesg-IA-2\banco-NoSql\subindo_imagem64_redis\Redis-Interface\Data\dados_alunos_redis.json"

# O prefixo r antes das aspas significa "raw string" (string bruta).
# Isso diz ao Python para interpretar as barras invertidas "\" literalmente.
# Sem esse r, o Python poderia tentar entender sequências como:
# \n = quebra de linha
# \t = tab
# Como caminho de Windows usa muitas barras invertidas,
# o r ajuda a evitar erro e facilita a escrita do caminho.

# Mostra o caminho salvo na variável para conferência.
print("Caminho do arquivo JSON:")
print(caminho_arquivo)
# Out:
# Caminho do arquivo JSON:
# C:\Users\nicol\OneDrive\Desktop\Fatesg-IA-2\banco-NoSql\subindo_imagem64_redis\Redis-Interface\Data\dados_alunos_redis.json

# %%
# Abre o arquivo usando a função open(...).
# A estrutura "with ... as ..." é a forma recomendada de abrir arquivos,
# porque ela garante que o arquivo será fechado automaticamente
# ao final do bloco, mesmo se acontecer erro no meio.
with open(caminho_arquivo, "r", encoding="utf-8") as f:
    # caminho_arquivo:
    #   é a variável que contém o endereço do arquivo no disco.
    #
    # "r":
    #   é o modo de abertura do arquivo.
    #   "r" vem de "read" = leitura.
    #   Isso quer dizer: vamos apenas ler o arquivo, não escrever nele.
    #
    # encoding="utf-8":
    #   define a codificação de texto usada para interpretar o conteúdo.
    #   UTF-8 é a codificação mais comum e suporta acentos e caracteres especiais.
    #
    # as f:
    #   significa que o arquivo aberto será referenciado pela variável f.
    #   Dentro do bloco, "f" representa esse arquivo.
    
    # json.load(f):
    # - json = biblioteca importada lá em cima
    # - load = método para ler JSON de um ARQUIVO
    # - f = arquivo já aberto
    #
    # Esse comando lê o conteúdo do arquivo JSON e converte
    # automaticamente para um objeto Python.
    #
    # Se o arquivo tiver:
    #   { ... }  -> vira um dict (dicionário)
    #   [ ... ]  -> vira uma list (lista)
    dados = json.load(f)

# Mostra o tipo do objeto carregado.
# type(dados) retorna a classe/tipo do conteúdo.
# Isso ajuda a saber se o JSON era um objeto ou uma lista.
print("Tipo do conteúdo carregado:")
print(type(dados))

# Mostra o conteúdo carregado de forma organizada.
# pprint = pretty print = impressão mais legível.
print("\nConteúdo do JSON lido do arquivo:")
pprint(dados)
# Out:
# Tipo do conteúdo carregado:
# <class 'dict'>
#
# Conteúdo do JSON lido do arquivo:
# {'aluno:1001': {'curso': 'Ciência da Computação',
#                 'disciplinas': ['Estrutura de Dados', 'Bancos de Dados', 'IA'],
#                 'idade': 22,
#                 'nome': 'Jefferson Silva',
#                 'semestre': 4,
#                 'status': 'Ativo'},
#  'aluno:1002': {'curso': 'Engenharia de Software',
#                 'disciplinas': ['Cálculo I', 'Lógica de Programação'],
#                 'idade': 20,
#                 'nome': 'Ana Beatriz Oliveira',
#                 'semestre': 2,
#                 'status': 'Ativo'},
#  'aluno:1003': {'curso': 'Sistemas de Informação',
#                 'disciplinas': ['Gestão de Projetos',
#                                 'Segurança da Informação'],
#                 'idade': 25,
#                 'nome': 'Lucas Marcante',
#                 'semestre': 8,
#                 'status': 'Formando'},
#  'aluno:1004': {'curso': 'Análise e Desenvolvimento de Sistemas',
#                 'disciplinas': ['Desenvolvimento Web',
#                                 'Arquitetura de Computadores'],
#                 'idade': 21,
#                 'nome': 'Mariana Costa',
#                 'semestre': 3,
#                 'status': 'Ativo'},
#  'aluno:1005': {'curso': 'Ciência da Computação',
#                 'disciplinas': ['Redes de Computadores',
#                                 'Sistemas Operacionais'],
#                 'idade': 23,
#                 'nome': 'Ricardo Souza',
#                 'semestre': 6,
#                 'status': 'Trancado'}}

# %%
# Cria a conexão com o Redis.
# redis.Redis(...) instancia um cliente/objeto de conexão.
# O nome da variável "r" é apenas uma convenção curta.
# Poderia ser "cliente", "conexao" ou outro nome qualquer.
r = redis.Redis(
    host="127.0.0.1",      # host = endereço do servidor Redis
                            # 127.0.0.1 significa "esta própria máquina" (localhost)
                            # Como seu código está rodando no Windows/host,
                            # e o Redis publicou a porta 6379, isso funciona.

    port=6379,             # port = porta de comunicação do Redis
                            # 6379 é a porta padrão do Redis

    decode_responses=True  # por padrão, muitas respostas do Redis vêm em bytes
                            # com True, a biblioteca converte automaticamente
                            # essas respostas para string normal do Python
                            # isso facilita leitura e manipulação
)

# Envia o comando PING para o Redis.
# ping() é um teste simples de conectividade.
# Se a conexão estiver funcionando, o retorno normalmente será True.
print("Resultado do teste de conexão com Redis:")
print(r.ping())
# Out:
# Resultado do teste de conexão com Redis:
# KeyboardInterrupt

# %%
# Define o nome da chave que será criada no Redis.
# No Redis, tudo é armazenado em pares:
# chave -> valor
#
# Aqui:
# chave = "json:alunos:arquivo"
# valor = será o conteúdo do JSON
#
# Esse padrão com ":" é muito usado para organizar nomes de chave.
# Exemplo:
# json:alunos:arquivo
# json:clientes:2026
# aluno:1
chave_redis = "json:alunos:arquivo"

# Converte o objeto Python armazenado em "dados" para TEXTO JSON.
# json.dumps(...) faz o caminho inverso do json.load(...):
#
# json.load(...)   -> arquivo JSON  -> objeto Python
# json.dumps(...)  -> objeto Python -> string JSON
json_texto = json.dumps(
    dados,                 # objeto Python que queremos transformar em JSON texto
    ensure_ascii=False,    # mantém caracteres acentuados normalmente
                           # se fosse True, alguns caracteres poderiam virar sequências escapadas
                           # como \u00e1 etc.

    indent=2               # adiciona identação de 2 espaços
                           # isso deixa o JSON salvo mais bonito e legível
)

# Salva no Redis usando o método set(...).
# set(chave, valor) significa:
# "grave este valor nesta chave"
#
# Aqui:
# - chave_redis = nome da chave
# - json_texto  = valor a ser salvo
r.set(chave_redis, json_texto)

# Exibe mensagem de confirmação.
print(f"JSON salvo com sucesso na chave: {chave_redis}")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\nicol\AppData\Local\Programs\Python\Python314\Lib\site-packages\redis\connection.py:1002, in AbstractConnection.connect_check_health(self, check_health, retry_socket_connect)
#    1001     else:
# -> 1002         sock = self._connect()
#    1003 except socket.timeout:
#
# File c:\Users\nicol\AppData\Local\Programs\Python\Python314\Lib\site-packages\redis\connection.py:1514, in Connection._connect(self)
#    1513 if err is not None:
# -> 1514     raise err
#    1515 raise OSError("socket.getaddrinfo returned an empty list")
#
# File c:\Users\nicol\AppData\Local\Programs\Python\Python314\Lib\site-packages\redis\connection.py:1498, in Connection._connect(self)
#    1497 # connect
# -> 1498 sock.connect(socket_address)
#    1500 # set the socket_timeout now that we're connected
#
# ConnectionRefusedError: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File c:\Users\nicol\AppData\Local\Programs\Python\Python314\Lib\site-packages\redis\retry.py:120, in Retry.call_with_retry(self, do, fail, is_retryable, with_failure_count)
#     119 try:
# --> 120     return do()
#     121 except self._supported_errors as error:
#
# File c:\Users\nicol\AppData\Local\Programs\Python\Python314\Lib\site-packages\redis\connection.py:976, in AbstractConnection.connect.<locals>.<lambda>()
#     973 # try once the socket connect with the handshake, retry the whole
#     974 # connect/handshake flow based on retry policy
#     975 self.retry.call_with_retry(
# --> 976     lambda: self.connect_check_health(
#     977         check_health=True, retry_socket_connect=False
#     978     ),
#     979     lambda error: self.disconnect(error),
#     980 )
#
# File c:\Users\nicol\AppData\Local\Programs\Python\Python314\Lib\site-packages\redis\connection.py:1024, in AbstractConnection.connect_check_health(self, check_health, retry_socket_connect)
#    1016     record_error_count(
#    1017         server_address=getattr(self, "host", None),
#    1018         server_port=getattr(self, "port", None),
#    (...)   1022         retry_attempts=actual_retry_attempts[0],
#    1023     )
# -> 1024     raise e
#    1026 self._sock = sock
#
# ConnectionError: Error 10061 connecting to 127.0.0.1:6379. Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 38
#      21 json_texto = json.dumps(
#      22     dados,                 # objeto Python que queremos transformar em JSON texto
#      23     ensure_ascii=False,    # mantém caracteres acentuados normalmente
#    (...)     28                            # isso deixa o JSON salvo mais bonito e legível
#      29 )
#      31 # Salva no Redis usando o método set(...).
#      32 # set(chave, valor) significa:
#      33 # "grave este valor nesta chave"
#    (...)     36 # - chave_redis = nome da chave
#      37 # - json_texto  = valor a ser salvo
# ---> 38 r.set(chave_redis, json_texto)
#      40 # Exibe mensagem de confirmação.
#      41 print(f"JSON salvo com sucesso na chave: {chave_redis}")
#
# File c:\Users\nicol\AppData\Local\Programs\Python\Python314\Lib\site-packages\redis\utils.py:493, in experimental_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     491 if len(filterable_args) > 0:
#     492     _check_experimental_args(func, filterable_args)
# --> 493 return func(*args, **kwargs)
#
# File c:\Users\nicol\AppData\Local\Programs\Python\Python314\Lib\site-packages\redis\commands\core.py:2668, in BasicKeyCommands.set(self, name, value, ex, px, nx, xx, keepttl, get, exat, pxat, ifeq, ifne, ifdeq, ifdne)
#    2665 if keepttl:
#    2666     pieces.append("KEEPTTL")
# -> 2668 return self.execute_command("SET", *pieces, **options)
#
# File c:\Users\nicol\AppData\Local\Programs\Python\Python314\Lib\site-packages\redis\client.py:716, in Redis.execute_command(self, *args, **options)
#     715 def execute_command(self, *args, **options):
# --> 716     return self._execute_command(*args, **options)
#
# File c:\Users\nicol\AppData\Local\Programs\Python\Python314\Lib\site-packages\redis\client.py:722, in Redis._execute_command(self, *args, **options)
#     720 pool = self.connection_pool
#     721 command_name = args[0]
# --> 722 conn = self.connection or pool.get_connection()
#     724 # Start timing for observability
#     725 start_time = time.monotonic()
#
# File c:\Users\nicol\AppData\Local\Programs\Python\Python314\Lib\site-packages\redis\utils.py:236, in deprecated_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     234 filterable_args = _get_filterable_args(func, args, kwargs, allowed_args)
#     235 _check_deprecated_args(func, filterable_args)
# --> 236 return func(*args, **kwargs)
#
# File c:\Users\nicol\AppData\Local\Programs\Python\Python314\Lib\site-packages\redis\connection.py:2960, in ConnectionPool.get_connection(self, command_name, *keys, **options)
#    2956     self._in_use_connections.add(connection)
#    2958 try:
#    2959     # ensure this connection is connected to Redis
# -> 2960     connection.connect()
#    2961     # connections that the pool provides should be ready to send
#    2962     # a command. if not, the connection was either returned to the
#    2963     # pool before all data has been read or the socket has been
#    2964     # closed. either way, reconnect and verify everything is good.
#    2965     try:
#
# File c:\Users\nicol\AppData\Local\Programs\Python\Python314\Lib\site-packages\redis\connection.py:975, in AbstractConnection.connect(self)
#     972 "Connects to the Redis server if not already connected"
#     973 # try once the socket connect with the handshake, retry the whole
#     974 # connect/handshake flow based on retry policy
# --> 975 self.retry.call_with_retry(
#     976     lambda: self.connect_check_health(
#     977         check_health=True, retry_socket_connect=False
#     978     ),
#     979     lambda error: self.disconnect(error),
#     980 )
#
# File c:\Users\nicol\AppData\Local\Programs\Python\Python314\Lib\site-packages\redis\retry.py:135, in Retry.call_with_retry(self, do, fail, is_retryable, with_failure_count)
#     133 backoff = self._backoff.compute(failures)
#     134 if backoff > 0:
# --> 135     sleep(backoff)
#
# KeyboardInterrupt:

# %%
# Busca do Redis o valor associado à chave informada.
# get(chave) = "me devolva o conteúdo salvo nessa chave"
valor_salvo = r.get(chave_redis)

# Mostra o tipo do valor retornado.
# Como usamos decode_responses=True,
# o retorno deverá ser uma string Python, não bytes.
print("Tipo do valor retornado pelo Redis:")
print(type(valor_salvo))

# Exibe o conteúdo bruto, exatamente como foi salvo.
# Neste caso, deve aparecer o JSON em formato texto.
print("\nValor salvo no Redis:")
print(valor_salvo)
# Out:
# Tipo do valor retornado pelo Redis:
# <class 'str'>
#
# Valor salvo no Redis:
# {
#   "aluno:1001": {
#     "nome": "Jefferson Silva",
#     "idade": 22,
#     "curso": "Ciência da Computação",
#     "semestre": 4,
#     "status": "Ativo",
#     "disciplinas": [
#       "Estrutura de Dados",
#       "Bancos de Dados",
#       "IA"
#     ]
#   },
#   "aluno:1002": {
#     "nome": "Ana Beatriz Oliveira",
#     "idade": 20,
#     "curso": "Engenharia de Software",
#     "semestre": 2,
#     "status": "Ativo",
#     "disciplinas": [
#       "Cálculo I",
#       "Lógica de Programação"
#     ]
#   },
#   "aluno:1003": {
#     "nome": "Lucas Marcante",
#     "idade": 25,
#     "curso": "Sistemas de Informação",
#     "semestre": 8,
#     "status": "Formando",
#     "disciplinas": [
#       "Gestão de Projetos",
#       "Segurança da Informação"
#     ]
#   },
#   "aluno:1004": {
#     "nome": "Mariana Costa",
#     "idade": 21,
#     "curso": "Análise e Desenvolvimento de Sistemas",
#     "semestre": 3,
#     "status": "Ativo",
#     "disciplinas": [
#       "Desenvolvimento Web",
#       "Arquitetura de Computadores"
#     ]
#   },
#   "aluno:1005": {
#     "nome": "Ricardo Souza",
#     "idade": 23,
#     "curso": "Ciência da Computação",
#     "semestre": 6,
#     "status": "Trancado",
#     "disciplinas": [
#       "Redes de Computadores",
#       "Sistemas Operacionais"
#     ]
#   }
# }

# %%
# Converte novamente a string JSON lida do Redis para objeto Python.
# Aqui usamos json.loads(...), com "s" no final.
#
# Diferença:
# json.load(arquivo_aberto)   -> lê JSON de arquivo
# json.loads(texto_json)      -> lê JSON de string
dados_recuperados = json.loads(valor_salvo)

# Mostra o tipo do objeto recuperado após a conversão.
print("Tipo do objeto recuperado a partir do texto JSON:")
print(type(dados_recuperados))

# Exibe o conteúdo convertido de volta para Python.
# Se o JSON original era objeto, aqui será dict.
# Se era lista, aqui será list.
print("\nConteúdo recuperado do Redis e convertido para Python:")
pprint(dados_recuperados)
# Out:
# Tipo do objeto recuperado a partir do texto JSON:
# <class 'dict'>
#
# Conteúdo recuperado do Redis e convertido para Python:
# {'aluno:1001': {'curso': 'Ciência da Computação',
#                 'disciplinas': ['Estrutura de Dados', 'Bancos de Dados', 'IA'],
#                 'idade': 22,
#                 'nome': 'Jefferson Silva',
#                 'semestre': 4,
#                 'status': 'Ativo'},
#  'aluno:1002': {'curso': 'Engenharia de Software',
#                 'disciplinas': ['Cálculo I', 'Lógica de Programação'],
#                 'idade': 20,
#                 'nome': 'Ana Beatriz Oliveira',
#                 'semestre': 2,
#                 'status': 'Ativo'},
#  'aluno:1003': {'curso': 'Sistemas de Informação',
#                 'disciplinas': ['Gestão de Projetos',
#                                 'Segurança da Informação'],
#                 'idade': 25,
#                 'nome': 'Lucas Marcante',
#                 'semestre': 8,
#                 'status': 'Formando'},
#  'aluno:1004': {'curso': 'Análise e Desenvolvimento de Sistemas',
#                 'disciplinas': ['Desenvolvimento Web',
#                                 'Arquitetura de Computadores'],
#                 'idade': 21,
#                 'nome': 'Mariana Costa',
#                 'semestre': 3,
#                 'status': 'Ativo'},
#  'aluno:1005': {'curso': 'Ciência da Computação',
#                 'disciplinas': ['Redes de Computadores',
#                                 'Sistemas Operacionais'],
#                 'idade': 23,
#                 'nome': 'Ricardo Souza',
#                 'semestre': 6,
#                 'status': 'Trancado'}}

# %%
import json
import redis
import base64
from pprint import pprint

# 1. CONFIGURAÇÃO DOS CAMINHOS
# Substituímos o caminho do arquivo JSON pelo caminho da sua IMAGEM
caminho_imagem = r"C:\Users\nicol\OneDrive\Desktop\Fatesg-IA-2\banco-NoSql\subindo_imagem64_redis\Redis-Interface\Data\cavalo.png"
chave_redis = "imagem:convertida:03"

# 2. CONVERSÃO DA IMAGEM PARA BASE64
# Abrimos como "rb" (read binary) porque imagem não é texto!
with open(caminho_imagem, "rb") as f:
    conteudo_binario = f.read()
    # Transforma os bytes em uma string de texto (Base64)
    imagem_base64 = base64.b64encode(conteudo_binario).decode('utf-8')

# Criamos o dicionário que será o nosso "JSON"
dados_imagem = {
    "nome_arquivo": "image03_grd.png",
    "formato": "png",
    "conteudo_64": imagem_base64
}

# 3. CONEXÃO COM O REDIS
r = redis.Redis(
    host="127.0.0.1",
    port=6379,
    decode_responses=True # Facilita a leitura como string depois
)

# Teste rápido de conexão
if r.ping():
    print("✅ Conectado ao Redis!")

    # 4. CONVERSÃO PARA STRING JSON E ENVIO
    # Transformamos o dicionário em uma string JSON para o Redis aceitar
    json_texto = json.dumps(dados_imagem)
    
    # Salvamos no banco
    r.set(chave_redis, json_texto)
    
    print(f"🚀 Sucesso! Imagem salva na chave: {chave_redis}")
    print(f"Tamanho do dado enviado: {len(json_texto)} caracteres.")
else:
    print("❌ Erro: Não foi possível conectar ao Redis. Verifique se o servidor está rodando.")
